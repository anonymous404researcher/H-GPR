% %%
disp ('executing gpml startup script...')
mydir = fileparts (mfilename ('fullpath'));                 % where am I located
addpath (mydir)
dirs = {'cov','doc','inf','lik','mean','prior','util'};           % core folders
for d = dirs, addpath (fullfile (mydir, d{1})), end
dirs = {{'util','minfunc'},{'util','minfunc','compiled'}};     % minfunc folders
for d = dirs, addpath (fullfile (mydir, d{1}{:})), end
% addpath([mydir,'/util/sparseinv'])
pkg load statistics
graphics_toolkit ('gnuplot')

warning('off','all');

rand('state',123456)
exp_name = 'ii2_conduct_temp10';
% Out:
% executing gpml startup script...

% %% [markdown]
% %load(exp_name)

% %%
n = 17263; nv = 2000; nt = 2000;
load ('./data/conduct.mat');

[ndata, ~] = size(M);
X = M(:,1:81);
Y = M(:,82);
R = randperm(ndata);        
ori_xvec_test = X(R(1:nt),:);
ori_yvec_test = Y(R(1:nt));
R(1:nt) = [];
ori_xvec_val = X(R(1:nv),:);          
ori_yvec_val = Y(R(1:nv));
R(1:nv) = [];
ori_xvec = X(R,:);
ori_yvec = Y(R);

% %%
ttcs = 400;
ttm = round(n / (ttcs/2));
% fast_induce_step = 50;
induce_step = 100;

xnorm = 1; ynorm = 1;

% %%
% input normalization
if xnorm == 1
    norm_xmean = mean(ori_xvec);
    norm_xstd = std(ori_xvec);
    xvec = (ori_xvec - repmat(norm_xmean,n,1)) ./ repmat(norm_xstd,n,1);    
    xvec_test = (ori_xvec_test - repmat(norm_xmean,nt,1)) ./ repmat(norm_xstd,nt,1);
    xvec_val = (ori_xvec_val - repmat(norm_xmean,nv,1)) ./ repmat(norm_xstd,nv,1);
else
    xvec = ori_xvec;
    xvec_test = ori_xvec_test;
    xvec_val = ori_xvec_val;
end

% %%
% output normalization
if ynorm == 1
    norm_fmean = mean(ori_yvec);
    norm_fstd = std(ori_yvec);
    yvec = (ori_yvec - norm_fmean) / norm_fstd;
    yvec_test = (ori_yvec_test - norm_fmean) / norm_fstd;
    yvec_val = (ori_yvec_val - norm_fmean) / norm_fstd;
else
    yvec = ori_yvec;
    yvec_test = ori_yvec_test;
    yvec_test_val = ori_yvec_val;
end

% %%
grls = 0.6:0.01:1.0; % percentage of remaining data to be test

% %%
sf2 = 1 ; ell = 1 ; sn2 = 0.1 ; 
d = size(xvec,2);
opts.Xnorm = 'N' ; opts.Ynorm = 'N' ;
opts.ell = ell ; opts.sf2 = sf2 ; opts.sn2 = sn2 ;
opts.meanfunc = []; opts.covfunc = @covSEard; opts.likfunc = @likGauss; opts.inffunc = @infGaussLik ;

meanfunc = [];                    % empty: don't use a mean function
covfunc = opts.covfunc;              % Squared Exponental covariance function
likfunc = opts.likfunc;              % Gaussian likelihood
inffunc = opts.inffunc;
km_iters = 1e4;
opts.induce_step = induce_step ;

% %%
kti = 1;
grbcm0_smse_rec = zeros(kti, 1);
vfe0_smse_rec = zeros(kti, 1);
grbcm0_msll_rec = zeros(kti, 1);
vfe0_msll_rec = zeros(kti, 1);

grbcm_smse_rec = zeros(kti, 1);
vfe_smse_rec = zeros(kti, 1);
grbcm_msll_rec = zeros(kti, 1);
vfe_msll_rec = zeros(kti, 1);

% %%
% use validation data to find the optimal gr
best_msll = inf;
best_msll_gr = 1;
best_smse = inf;
best_smse_gr = 1;
ki = 1;

% %% [markdown]
% # find ratio

% %%
dcs = round(ttcs/2);
m = ttm;

n_per = dcs ; % size of Dc

% %%
Indics = randperm(n) ;
I_com = Indics(1:n_per) ; % randomly select communication set
[idx, C] = kmeans(xvec, m,'MaxIter',km_iters);    

% hyp.cov = log([ones(d,1)*ell;sf2]); hyp.lik = log(sn2); hyp.mean = [];    
opts.numOptFC = 30 ;
opts.Ms = m+1;
opts.xvec = xvec;
opts.yvec = yvec;
opts.induce_size = dcs;
opts.grbcm_baseline = 0;
opts.global_index = ones(n,1);
opts.I_com = I_com;
% opts.inffunc = @infGaussLik; opts.meanfunc = meanfunc; opts.likfunc = likfunc;
opts.covfunc = covfunc;
covfuncF = {@apxSparse, {opts.covfunc}, xvec(I_com,:)};
opts.covfuncF = covfuncF;
opts.compute_hyp = 0;

% %%
g_opts = opts;
g_opts.compute_hyp = 1;
g_opts.grbcm_baseline = 1;
g_opts.global_index = ones(n,1);
g_models = aggregation_train_GRBCM_VS_apx(xvec,yvec,idx,g_opts); 
opts.hyp = g_models{1}.hyp;
g_opts.hyp = g_models{1}.hyp;
[tmu,ts2, ~] =  aggregation_predict(xvec_val,g_models,'GRBCM', 1, g_opts);
if ynorm==1
    tmu = tmu * norm_fstd + norm_fmean;
    ts2 = ts2 * norm_fstd^2;
end
[grbcmMSE,grbcmSMSE,grbcmMSLL] = evaluate2(ori_xvec, ori_yvec, ori_xvec_val, ori_yvec_val, tmu, ts2);
fprintf('%s (Dc size %d): MSE %6.8f, SMSE %6.8f, MSLL %6.8f\r\n', 'GRBCM', n_per, grbcmMSE,grbcmSMSE,grbcmMSLL);
% grbcm0_smse_rec(ki) = grbcmSMSE; grbcm0_msll_rec(ki) = grbcmMSLL;
g_opts.compute_hyp = 0;
% Out:
% Optimizing hyps in training...
% Linesearch     30;  Value 8.389233e+03
% GRBCM (Dc size 200): MSE 173.18768868, SMSE 0.13740422, MSLL -1.16467892

% %%
vfe_opts = opts;
vfe_opts.induce_type = 'VFE_opt';
xu = xvec(I_com, :);
inffunc = @(varargin) infGaussLik(varargin{:}, struct('s', 0.0));
vfe_hyp = opts.hyp;
vfe_hyp.xu = xu;
[vfe_hyp, tmp_nlzs] = minimize(vfe_hyp,@sp_gp,-vfe_opts.induce_step,inffunc,meanfunc,covfuncF,likfunc,xvec,yvec);
vfe_opts.hyp = opts.hyp;
vfe_opts.xu = vfe_hyp.xu;
vfe_opts.inffunc = @infGaussLik; vfe_opts.meanfunc = meanfunc; vfe_opts.covfuncF = covfuncF; vfe_opts.likfunc = likfunc;
vfe_opts.covfunc = covfunc;
[tmu, ts2] = gp(vfe_hyp, @infGaussLik, meanfunc, covfuncF, likfunc, xvec, yvec, xvec_val);
if ynorm==1
    tmu = tmu * norm_fstd + norm_fmean;
    ts2 = ts2 * norm_fstd^2;
end
[vfeMSE,vfeSMSE,vfeMSLL] = evaluate2(ori_xvec, ori_yvec, ori_xvec_val, ori_yvec_val, tmu, ts2);
fprintf('%s (Dc size %d): MSE %6.8f, SMSE %6.8f, MSLL %6.8f\r\n', 'VFE', n_per, vfeMSE,vfeSMSE,vfeMSLL);
% vfe0_smse_rec(ki) = vfeSMSE; vfe0_msll_rec(ki) = vfeMSLL;
[yu, su] = gp(vfe_hyp, @infGaussLik, meanfunc, covfuncF, likfunc, xvec, yvec, vfe_opts.xu);
vfe_opts.yu = yu; vfe_opts.su = su;
% Out:
% Function evaluation    100;  Value 8.925617e+04
% VFE (Dc size 200): MSE 431.98590594, SMSE 0.34273041, MSLL -0.63418872

% %%
models = aggregation_train_GRBCM_VS_apx(xvec,yvec,idx,vfe_opts); % use hyp of vfe
[tmu,ts2] =  aggregation_predict_GRBCM_VS_apx(xvec_val,models,vfe_opts);
if ynorm==1
    tmu = tmu * norm_fstd + norm_fmean;
    ts2 = ts2 * norm_fstd^2;
end
[MSE,SMSE,MSLL] = evaluate2(ori_xvec, ori_yvec, ori_xvec_val, ori_yvec_val, tmu, ts2);
fprintf('%s (Dc size %d): \r\nMSE %6.8f, SMSE %6.4f, MSLL %6.4f\r\n', 'GRBCM++ (VFE)', n_per, MSE,SMSE,MSLL);
% Out:
% GRBCM++ (VFE) (Dc size 200):
% MSE 163.87482327, SMSE 0.1300, MSLL -1.1873

% %%
sig_temp = 10;
dcs_ecs_r = sigmoid(-MSLL+grbcmMSLL, sig_temp)
dcs = round(ttcs*dcs_ecs_r)
ecs = ttcs - dcs
m = round(n / ecs)
% Out:
% dcs_ecs_r =  0.55639
% dcs =  223
% ecs =  177
% m =  98

% %% [markdown]
% # New unbalanced

% %%
n_per = dcs ; % size of Dc
Indics = randperm(n) ;
I_com = Indics(1:n_per) ; % randomly select communication set
[idx, C] = kmeans(xvec, m,'MaxIter',km_iters);    

% hyp.cov = log([ones(d,1)*ell;sf2]); hyp.lik = log(sn2); hyp.mean = [];    
opts.numOptFC = 30 ;
opts.Ms = m+1;
opts.xvec = xvec;
opts.yvec = yvec;
opts.induce_size = dcs;
opts.grbcm_baseline = 0;
opts.global_index = ones(n,1);
opts.I_com = I_com;
% opts.inffunc = @infGaussLik; opts.meanfunc = meanfunc; opts.likfunc = likfunc;
opts.covfunc = covfunc;
covfuncF = {@apxSparse, {opts.covfunc}, xvec(I_com,:)};
opts.covfuncF = covfuncF;
opts.compute_hyp = 0;

% %%
g_opts = opts;
g_opts.compute_hyp = 0;
g_opts.grbcm_baseline = 1;
g_opts.global_index = ones(n,1);
g_models = aggregation_train_GRBCM_VS_apx(xvec,yvec,idx,g_opts); 
opts.hyp = g_models{1}.hyp;
g_opts.hyp = g_models{1}.hyp;
[tmu,ts2, ~] =  aggregation_predict(xvec_test,g_models,'GRBCM', 1, g_opts);
if ynorm==1
    tmu = tmu * norm_fstd + norm_fmean;
    ts2 = ts2 * norm_fstd^2;
end
[grbcmMSE,grbcmSMSE,grbcmMSLL] = evaluate2(ori_xvec, ori_yvec, ori_xvec_test, ori_yvec_test, tmu, ts2);
fprintf('%s (Dc size %d): MSE %6.8f, SMSE %6.8f, MSLL %6.8f\r\n', 'GRBCM', n_per, grbcmMSE,grbcmSMSE,grbcmMSLL);
% grbcm0_smse_rec(ki) = grbcmSMSE; grbcm0_msll_rec(ki) = grbcmMSLL;
g_opts.compute_hyp = 0;
% Out:
% GRBCM (Dc size 223): MSE 154.13107493, SMSE 0.13197185, MSLL -1.12260313

% %%
% % VFE Baseline
vfe_opts = opts;
vfe_opts.induce_type = 'VFE_opt';
xu = xvec(I_com, :);
vfe_hyp = opts.hyp;
vfe_hyp.xu = xu;
vfe_hyp = minimize(vfe_hyp,@sp_gp,-vfe_opts.induce_step,inffunc,meanfunc,covfuncF,likfunc,xvec,yvec);
vfe_opts.hyp = opts.hyp;
vfe_opts.xu = vfe_hyp.xu;
vfe_opts.inffunc = @infGaussLik; vfe_opts.meanfunc = meanfunc; vfe_opts.covfuncF = covfuncF; vfe_opts.likfunc = likfunc;
vfe_opts.covfunc = covfunc;
[tmu, ts2] = gp(vfe_hyp, @infGaussLik, meanfunc, covfuncF, likfunc, xvec, yvec, xvec_test);
if ynorm==1
    tmu = tmu * norm_fstd + norm_fmean;
    ts2 = ts2 * norm_fstd^2;
end
[vfeMSE,vfeSMSE,vfeMSLL] = evaluate2(ori_xvec, ori_yvec, ori_xvec_test, ori_yvec_test, tmu, ts2);
fprintf('%s (Dc size %d): MSE %6.8f, SMSE %6.8f, MSLL %6.8f\r\n', 'VFE baseline', n_per, vfeMSE,vfeSMSE,vfeMSLL);
% vfe0_smse_rec(ki) = vfeSMSE; vfe0_msll_rec(ki) = vfeMSLL;
[yu, su] = gp(vfe_hyp, @infGaussLik, meanfunc, covfuncF, likfunc, xvec, yvec, vfe_opts.xu);
vfe_opts.yu = yu; vfe_opts.su = su;
% Out:
% Function evaluation    100;  Value 8.448225e+04
% VFE baseline (Dc size 223): MSE 387.19689247, SMSE 0.33153009, MSLL -0.61680613

% %%
sp_opts = opts;
sp_opts.induce_type = 'SPGP_opt';
hyp_init(1:d,1) = -2*opts.hyp.cov(1:d);
hyp_init(d+1,1) = 2*opts.hyp.cov(d+1);
hyp_init(d+2,1) = 2*opts.hyp.lik;

sp_opts.induce_size = dcs;
xu = xvec(I_com, :);
w_init = [reshape(xu,sp_opts.induce_size*d,1);hyp_init];
[w,f] = minimize(w_init,'spgp_lik_nohyp',-sp_opts.induce_step,yvec,xvec,sp_opts.induce_size);
xb = reshape(w(1:sp_opts.induce_size*d,1),sp_opts.induce_size,d);
sp_opts.xu = xb;
sp_opts.sp_hyp = w(sp_opts.induce_size*d+1:end,1);
sp_opts.hyp = opts.hyp;

[tmu,ts2] = spgp_pred(sp_opts.yvec,sp_opts.xvec,sp_opts.xu,xvec_test,sp_opts.sp_hyp);
if ynorm==1
    tmu = tmu * norm_fstd + norm_fmean;
    ts2 = ts2 * norm_fstd^2;
end
[spgpMSE,spgpSMSE,spgpMSLL] = evaluate2(ori_xvec, ori_yvec, ori_xvec_test, ori_yvec_test, tmu, ts2);
fprintf('%s (Dc size %d): MSE %6.8f, SMSE %6.8f, MSLL %6.8f\r\n', 'SPSG baseline', n_per, spgpMSE,spgpSMSE,spgpMSLL);
% spgp0_smse_rec(ki) = spgpSMSE; spgp0_msll_rec(ki) = spgpMSLL;
[yu,su] = spgp_pred(sp_opts.yvec,sp_opts.xvec,sp_opts.xu,sp_opts.xu,sp_opts.sp_hyp);
sp_opts.yu = yu; sp_opts.su = su;
% Out:
% Function evaluation     99;  Value 1.576475e+04
% SPSG baseline (Dc size 223): MSE 501.01350984, SMSE 0.42898344, MSLL -0.53684559

% %%
disp('validation results')
% Out:
% validation results

% %%
% compute informatic importance
ds = zeros(n, m);
for i=1:n
    for j=1:m
        %ds(i,j) = muti1(i)-muti2(j,i)+muti1(j)-muti2(i,j);
        ds(i,j) = norm(xvec(i, :) - C(j,:));
    end
end
% 1st closest cluster centers
[~, fcc] = min(ds, [], 2);
% set to inf
for i=1:n
    ds(i, fcc(i)) = 1e10;
end
% 2st closest cluster centers
[~, scc] = min(ds, [], 2);
rk = zeros(n, 1);
for iik=1:n
    if mod(iik, 1e2)==0
        fprintf('processing distance: %d/%d\n', iik, n);
    end
    i = fcc(iik);
    [tmp_mu, tmp_sig2] = gp(opts.hyp,inffunc,meanfunc, ...
        covfunc,likfunc,g_models{i+1}.X,g_models{i+1}.Y,xvec(iik,:));
    h1 = 0.5*log(tmp_sig2);
    j = scc(iik);
%     [tmp_mu, tmp_sig2] = gp(opts.hyp,inffunc,meanfunc, ...
%         covfunc,likfunc,[g_models{i+1}.X;g_models{j+1}.X],[g_models{i+1}.Y;g_models{j+1}.Y],xvec(iik,:));
    [tmp_mu, tmp_sig2] = gp(opts.hyp,inffunc,meanfunc, ...
        covfunc,likfunc,[g_models{j+1}.X],[g_models{j+1}.Y],xvec(iik,:));
    h2 = 0.5*log(tmp_sig2);
    rk(iik) = h2 - h1; % importance is the difference between mutual information
end
% Out:
% processing distance: 100/17263
% processing distance: 200/17263
% processing distance: 300/17263
% processing distance: 400/17263
% processing distance: 500/17263
% processing distance: 600/17263
% processing distance: 700/17263
% processing distance: 800/17263
% processing distance: 900/17263
% processing distance: 1000/17263
% processing distance: 1100/17263
% processing distance: 1200/17263
% processing distance: 1300/17263
% processing distance: 1400/17263
% processing distance: 1500/17263
% processing distance: 1600/17263
% processing distance: 1700/17263
% processing distance: 1800/17263
% processing distance: 1900/17263
% processing distance: 2000/17263
% processing distance: 2100/17263
% processing distance: 2200/17263
% processing distance: 2300/17263
% processing distance: 2400/17263
% processing distance: 2500/17263
% processing distance: 2600/17263
% processing distance: 2700/17263
% processing distance: 2800/17263
% processing distance: 2900/17263
% processing distance: 3000/17263
% processing distance: 3100/17263
% processing distance: 3200/17263
% processing distance: 3300/17263
% processing distance: 3400/17263
% processing distance: 3500/17263
% processing distance: 3600/17263
% processing distance: 3700/17263
% processing distance: 3800/17263
% processing distance: 3900/17263
% processing distance: 4000/17263
% processing distance: 4100/17263
% processing distance: 4200/17263
% processing distance: 4300/17263
% processing distance: 4400/17263
% processing distance: 4500/17263
% processing distance: 4600/17263
% processing distance: 4700/17263
% processing distance: 4800/17263
% processing distance: 4900/17263
% processing distance: 5000/17263
% processing distance: 5100/17263
% processing distance: 5200/17263
% processing distance: 5300/17263
% processing distance: 5400/17263
% processing distance: 5500/17263
% processing distance: 5600/17263
% processing distance: 5700/17263
% processing distance: 5800/17263
% processing distance: 5900/17263
% processing distance: 6000/17263
% processing distance: 6100/17263
% processing distance: 6200/17263
% processing distance: 6300/17263
% processing distance: 6400/17263
% processing distance: 6500/17263
% processing distance: 6600/17263
% processing distance: 6700/17263
% processing distance: 6800/17263
% processing distance: 6900/17263
% processing distance: 7000/17263
% processing distance: 7100/17263
% processing distance: 7200/17263
% processing distance: 7300/17263
% processing distance: 7400/17263
% processing distance: 7500/17263
% processing distance: 7600/17263
% processing distance: 7700/17263
% processing distance: 7800/17263
% processing distance: 7900/17263
% processing distance: 8000/17263
% processing distance: 8100/17263
% processing distance: 8200/17263
% processing distance: 8300/17263
% processing distance: 8400/17263
% processing distance: 8500/17263
% processing distance: 8600/17263
% processing distance: 8700/17263
% processing distance: 8800/17263
% processing distance: 8900/17263
% processing distance: 9000/17263
% processing distance: 9100/17263
% processing distance: 9200/17263
% processing distance: 9300/17263
% processing distance: 9400/17263
% processing distance: 9500/17263
% processing distance: 9600/17263
% processing distance: 9700/17263
% processing distance: 9800/17263
% processing distance: 9900/17263
% processing distance: 10000/17263
% processing distance: 10100/17263
% processing distance: 10200/17263
% processing distance: 10300/17263
% processing distance: 10400/17263
% processing distance: 10500/17263
% processing distance: 10600/17263
% processing distance: 10700/17263
% processing distance: 10800/17263
% processing distance: 10900/17263
% processing distance: 11000/17263
% processing distance: 11100/17263
% processing distance: 11200/17263
% processing distance: 11300/17263
% processing distance: 11400/17263
% processing distance: 11500/17263
% processing distance: 11600/17263
% processing distance: 11700/17263
% processing distance: 11800/17263
% processing distance: 11900/17263
% processing distance: 12000/17263
% processing distance: 12100/17263
% processing distance: 12200/17263
% processing distance: 12300/17263
% processing distance: 12400/17263
% processing distance: 12500/17263
% processing distance: 12600/17263
% processing distance: 12700/17263
% processing distance: 12800/17263
% processing distance: 12900/17263
% processing distance: 13000/17263
% processing distance: 13100/17263
% processing distance: 13200/17263
% processing distance: 13300/17263
% processing distance: 13400/17263
% processing distance: 13500/17263
% processing distance: 13600/17263
% processing distance: 13700/17263
% processing distance: 13800/17263
% processing distance: 13900/17263
% processing distance: 14000/17263
% processing distance: 14100/17263
% processing distance: 14200/17263
% processing distance: 14300/17263
% processing distance: 14400/17263
% processing distance: 14500/17263
% processing distance: 14600/17263
% processing distance: 14700/17263
% processing distance: 14800/17263
% processing distance: 14900/17263
% processing distance: 15000/17263
% processing distance: 15100/17263
% processing distance: 15200/17263
% processing distance: 15300/17263
% processing distance: 15400/17263
% processing distance: 15500/17263
% processing distance: 15600/17263
% processing distance: 15700/17263
% processing distance: 15800/17263
% processing distance: 15900/17263
% processing distance: 16000/17263
% processing distance: 16100/17263
% processing distance: 16200/17263
% processing distance: 16300/17263
% processing distance: 16400/17263
% processing distance: 16500/17263
% processing distance: 16600/17263
% processing distance: 16700/17263
% processing distance: 16800/17263
% processing distance: 16900/17263
% processing distance: 17000/17263
% processing distance: 17100/17263
% processing distance: 17200/17263

% %%
for kj=1:length(grls) % test/validate different remaining percentage
    kj
    gr=grls(kj)

    % remove data, and use sparse approximation
    crk = rk;
    [~, crk_idx] = sort(crk, 'descend');
    rn = round(n*gr);
    global_index = crk_idx(1:rn);
    global_index = zeros(n,1);
    global_index(crk_idx(1:rn)) = 1; % select remaining data according to the importance
    
    vfe_opts.global_index = global_index;
    models = aggregation_train_GRBCM_VS_apx(xvec,yvec,idx,vfe_opts); % use hyp of vfe
    [tmu,ts2] = aggregation_predict_GRBCM_VS_apx(xvec_val,models,vfe_opts);
    if ynorm==1
        tmu = tmu * norm_fstd + norm_fmean;
        ts2 = ts2 * norm_fstd^2;
    end
    [MSE,SMSE,MSLL] = evaluate2(ori_xvec, ori_yvec, ori_xvec_val, ori_yvec_val, tmu, ts2);
    fprintf('%s (Dc size %d): \r\nMSE %6.8f, SMSE %6.8f, MSLL %6.8f\r\n', 'GRBCM++', n_per, MSE,SMSE,MSLL);
    vfe_gr_smse(ki,kj) = SMSE; vfe_gr_msll(ki,kj) = MSLL;
    if MSLL < best_msll
        best_msll = MSLL; best_msll_gr = gr;
    end
    if SMSE < best_smse
        best_smse = SMSE; best_smse_gr = gr;
    end
    
    sp_opts.global_index = global_index;
    models = aggregation_train_GRBCM_VS_apx(xvec,yvec,idx,sp_opts); % use hyp of vfe
    [tmu,ts2] = aggregation_predict_GRBCM_VS_apx(xvec_val,models,sp_opts);
    if ynorm==1
        tmu = tmu * norm_fstd + norm_fmean;
        ts2 = ts2 * norm_fstd^2;
    end
    [MSE,SMSE,MSLL] = evaluate2(ori_xvec, ori_yvec, ori_xvec_val, ori_yvec_val, tmu, ts2);
    fprintf('%s (Dc size %d): \r\nMSE %6.8f, SMSE %6.8f, MSLL %6.8f\r\n', 'GRBCM++', n_per, MSE,SMSE,MSLL);
    spgp_gr_smse(ki,kj) = SMSE; spgp_gr_msll(ki,kj) = MSLL;
end
% Out:
% kj =  1
% gr =  0.60000
% GRBCM++ (Dc size 223):
% MSE 207.92997138, SMSE 0.16496817, MSLL -1.07689446
% GRBCM++ (Dc size 223):
% MSE 246.84221265, SMSE 0.19584050, MSLL -1.03208467
% kj =  2
% gr =  0.61000
% GRBCM++ (Dc size 223):
% MSE 205.34540532, SMSE 0.16291762, MSLL -1.08154447
% GRBCM++ (Dc size 223):
% MSE 243.38735782, SMSE 0.19309947, MSLL -1.03717481
% kj =  3
% gr =  0.62000
% GRBCM++ (Dc size 223):
% MSE 199.70398415, SMSE 0.15844181, MSLL -1.09145633
% GRBCM++ (Dc size 223):
% MSE 235.80709664, SMSE 0.18708542, MSLL -1.04920374
% kj =  4
% gr =  0.63000
% GRBCM++ (Dc size 223):
% MSE 197.79596563, SMSE 0.15692802, MSLL -1.09828641
% GRBCM++ (Dc size 223):
% MSE 232.14821490, SMSE 0.18418252, MSLL -1.05813848
% kj =  5
% gr =  0.64000
% GRBCM++ (Dc size 223):
% MSE 193.21757522, SMSE 0.15329560, MSLL -1.10571266
% GRBCM++ (Dc size 223):
% MSE 222.54391542, SMSE 0.17656263, MSLL -1.07007819
% kj =  6
% gr =  0.65000
% GRBCM++ (Dc size 223):
% MSE 191.96354137, SMSE 0.15230067, MSLL -1.10996818
% GRBCM++ (Dc size 223):
% MSE 219.49174444, SMSE 0.17414109, MSLL -1.07623650
% kj =  7
% gr =  0.66000
% GRBCM++ (Dc size 223):
% MSE 189.76501532, SMSE 0.15055640, MSLL -1.11553678
% GRBCM++ (Dc size 223):
% MSE 215.46368389, SMSE 0.17094529, MSLL -1.08280480
% kj =  8
% gr =  0.67000
% GRBCM++ (Dc size 223):
% MSE 187.67057653, SMSE 0.14889471, MSLL -1.11958659
% GRBCM++ (Dc size 223):
% MSE 213.28652484, SMSE 0.16921797, MSLL -1.08177296
% kj =  9
% gr =  0.68000
% GRBCM++ (Dc size 223):
% MSE 184.36045377, SMSE 0.14626851, MSLL -1.12507851
% GRBCM++ (Dc size 223):
% MSE 210.14192023, SMSE 0.16672310, MSLL -1.08531313
% kj =  10
% gr =  0.69000
% GRBCM++ (Dc size 223):
% MSE 183.50697896, SMSE 0.14559138, MSLL -1.12441400
% GRBCM++ (Dc size 223):
% MSE 203.00904234, SMSE 0.16106399, MSLL -1.10194574
% kj =  11
% gr =  0.70000
% GRBCM++ (Dc size 223):
% MSE 184.13066213, SMSE 0.14608620, MSLL -1.12218380
% GRBCM++ (Dc size 223):
% MSE 201.75165048, SMSE 0.16006640, MSLL -1.09765302
% kj =  12
% gr =  0.71000
% GRBCM++ (Dc size 223):
% MSE 182.99281712, SMSE 0.14518345, MSLL -1.12463229
% GRBCM++ (Dc size 223):
% MSE 200.07269694, SMSE 0.15873434, MSLL -1.09846142
% kj =  13
% gr =  0.72000
% GRBCM++ (Dc size 223):
% MSE 181.91223667, SMSE 0.14432613, MSLL -1.12744133
% GRBCM++ (Dc size 223):
% MSE 200.30250019, SMSE 0.15891666, MSLL -1.09623024
% kj =  14
% gr =  0.73000
% GRBCM++ (Dc size 223):
% MSE 182.17213905, SMSE 0.14453234, MSLL -1.12616932
% GRBCM++ (Dc size 223):
% MSE 200.56272896, SMSE 0.15912312, MSLL -1.09471887
% kj =  15
% gr =  0.74000
% GRBCM++ (Dc size 223):
% MSE 182.07557369, SMSE 0.14445572, MSLL -1.12692854
% GRBCM++ (Dc size 223):
% MSE 200.68278157, SMSE 0.15921837, MSLL -1.09448005
% kj =  16
% gr =  0.75000
% GRBCM++ (Dc size 223):
% MSE 182.05336072, SMSE 0.14443810, MSLL -1.12625344
% GRBCM++ (Dc size 223):
% MSE 199.08974437, SMSE 0.15795448, MSLL -1.09693229
% kj =  17
% gr =  0.76000
% GRBCM++ (Dc size 223):
% MSE 179.31037264, SMSE 0.14226186, MSLL -1.12940414
% GRBCM++ (Dc size 223):
% MSE 196.37654221, SMSE 0.15580187, MSLL -1.09798957
% kj =  18
% gr =  0.77000
% GRBCM++ (Dc size 223):
% MSE 177.51193861, SMSE 0.14083501, MSLL -1.13338893
% GRBCM++ (Dc size 223):
% MSE 195.56801592, SMSE 0.15516040, MSLL -1.09689233
% kj =  19
% gr =  0.78000
% GRBCM++ (Dc size 223):
% MSE 176.73757871, SMSE 0.14022065, MSLL -1.13292781
% GRBCM++ (Dc size 223):
% MSE 195.17039506, SMSE 0.15484494, MSLL -1.09564721
% kj =  20
% gr =  0.79000
% GRBCM++ (Dc size 223):
% MSE 177.21977883, SMSE 0.14060322, MSLL -1.12849478
% GRBCM++ (Dc size 223):
% MSE 196.28208019, SMSE 0.15572693, MSLL -1.08727195
% kj =  21
% gr =  0.80000
% GRBCM++ (Dc size 223):
% MSE 177.77373561, SMSE 0.14104272, MSLL -1.12787236
% GRBCM++ (Dc size 223):
% MSE 198.18115766, SMSE 0.15723363, MSLL -1.08352525
% kj =  22
% gr =  0.81000
% GRBCM++ (Dc size 223):
% MSE 177.37893669, SMSE 0.14072949, MSLL -1.13012355
% GRBCM++ (Dc size 223):
% MSE 196.70594682, SMSE 0.15606322, MSLL -1.08691306
% kj =  23
% gr =  0.82000
% GRBCM++ (Dc size 223):
% MSE 177.69719089, SMSE 0.14098199, MSLL -1.12904873
% GRBCM++ (Dc size 223):
% MSE 197.13117037, SMSE 0.15640058, MSLL -1.08547268
% kj =  24
% gr =  0.83000
% GRBCM++ (Dc size 223):
% MSE 175.26004303, SMSE 0.13904840, MSLL -1.13664981
% GRBCM++ (Dc size 223):
% MSE 190.54070510, SMSE 0.15117182, MSLL -1.10738580
% kj =  25
% gr =  0.84000
% GRBCM++ (Dc size 223):
% MSE 174.75800360, SMSE 0.13865009, MSLL -1.14534632
% GRBCM++ (Dc size 223):
% MSE 189.91899838, SMSE 0.15067857, MSLL -1.11754160
% kj =  26
% gr =  0.85000
% GRBCM++ (Dc size 223):
% MSE 173.20386115, SMSE 0.13741706, MSLL -1.14914650
% GRBCM++ (Dc size 223):
% MSE 187.62825117, SMSE 0.14886113, MSLL -1.12171693
% kj =  27
% gr =  0.86000
% GRBCM++ (Dc size 223):
% MSE 171.18724502, SMSE 0.13581711, MSLL -1.15178936
% GRBCM++ (Dc size 223):
% MSE 184.36073201, SMSE 0.14626873, MSLL -1.12568594
% kj =  28
% gr =  0.87000
% GRBCM++ (Dc size 223):
% MSE 170.49728879, SMSE 0.13526971, MSLL -1.15347567
% GRBCM++ (Dc size 223):
% MSE 182.72096034, SMSE 0.14496776, MSLL -1.12733138
% kj =  29
% gr =  0.88000
% GRBCM++ (Dc size 223):
% MSE 169.14158457, SMSE 0.13419411, MSLL -1.15798939
% GRBCM++ (Dc size 223):
% MSE 179.86393596, SMSE 0.14270105, MSLL -1.13450524
% kj =  30
% gr =  0.89000
% GRBCM++ (Dc size 223):
% MSE 169.37237385, SMSE 0.13437722, MSLL -1.15582699
% GRBCM++ (Dc size 223):
% MSE 180.91710803, SMSE 0.14353662, MSLL -1.12853757
% kj =  31
% gr =  0.90000
% GRBCM++ (Dc size 223):
% MSE 169.37799285, SMSE 0.13438167, MSLL -1.15494635
% GRBCM++ (Dc size 223):
% MSE 178.31605222, SMSE 0.14147298, MSLL -1.13454395
% kj =  32
% gr =  0.91000
% GRBCM++ (Dc size 223):
% MSE 169.53791563, SMSE 0.13450856, MSLL -1.15101319
% GRBCM++ (Dc size 223):
% MSE 177.62647309, SMSE 0.14092588, MSLL -1.13020853
% kj =  33
% gr =  0.92000
% GRBCM++ (Dc size 223):
% MSE 168.92612101, SMSE 0.13402317, MSLL -1.15245628
% GRBCM++ (Dc size 223):
% MSE 176.98118139, SMSE 0.14041392, MSLL -1.13178935
% kj =  34
% gr =  0.93000
% GRBCM++ (Dc size 223):
% MSE 167.80763428, SMSE 0.13313578, MSLL -1.15545998
% GRBCM++ (Dc size 223):
% MSE 175.54364738, SMSE 0.13927340, MSLL -1.13514788
% kj =  35
% gr =  0.94000
% GRBCM++ (Dc size 223):
% MSE 167.39829266, SMSE 0.13281101, MSLL -1.15692658
% GRBCM++ (Dc size 223):
% MSE 175.27804440, SMSE 0.13906268, MSLL -1.13472953
% kj =  36
% gr =  0.95000
% GRBCM++ (Dc size 223):
% MSE 165.89521111, SMSE 0.13161849, MSLL -1.15941096
% GRBCM++ (Dc size 223):
% MSE 172.19001847, SMSE 0.13661269, MSLL -1.14123463
% kj =  37
% gr =  0.96000
% GRBCM++ (Dc size 223):
% MSE 165.50929918, SMSE 0.13131232, MSLL -1.16038164
% GRBCM++ (Dc size 223):
% MSE 169.97925244, SMSE 0.13485870, MSLL -1.15034082
% kj =  38
% gr =  0.97000
% GRBCM++ (Dc size 223):
% MSE 165.29014035, SMSE 0.13113844, MSLL -1.16118487
% GRBCM++ (Dc size 223):
% MSE 169.65238219, SMSE 0.13459937, MSLL -1.15163540
% kj =  39
% gr =  0.98000
% GRBCM++ (Dc size 223):
% MSE 164.55909477, SMSE 0.13055844, MSLL -1.16361603
% GRBCM++ (Dc size 223):
% MSE 168.72198136, SMSE 0.13386121, MSLL -1.15507194
% kj =  40
% gr =  0.99000
% GRBCM++ (Dc size 223):
% MSE 162.66499410, SMSE 0.12905569, MSLL -1.17260276
% GRBCM++ (Dc size 223):
% MSE 167.52510873, SMSE 0.13291163, MSLL -1.16107468
% kj =  41
% gr =  1
% GRBCM++ (Dc size 223):
% MSE 162.46281253, SMSE 0.12889529, MSLL -1.17313953
% GRBCM++ (Dc size 223):
% MSE 167.26078180, SMSE 0.13270191, MSLL -1.16199856

% %%
fprintf('best msll gr %6.8f, best MSLL %6.8f\r\n', best_msll_gr, best_msll);
fprintf('best smse gr %6.8f, best SMSE %6.8f\r\n', best_smse_gr, best_smse);
% Out:
% best msll gr 1.00000000, best MSLL -1.17313953
% best smse gr 1.00000000, best SMSE 0.12889529

% %%
for ki=1:kti
    for gr = [best_msll_gr, best_smse_gr, 1.0]
        gr
        crk = rk;
        crk(I_com) = -1e10;
        [~, crk_idx] = sort(crk, 'descend');
        rn = round(n*gr);
        global_index = zeros(n,1);
        global_index(crk_idx(1:rn)) = 1; % select remaining data according to the importance
           
        vfe_opts.global_index = global_index;
        models = aggregation_train_GRBCM_VS_apx(xvec,yvec,idx,vfe_opts); % use hyp of vfe
        [tmu,ts2] =  aggregation_predict_GRBCM_VS_apx(xvec_test,models,vfe_opts);
        if ynorm==1
            tmu = tmu * norm_fstd + norm_fmean;
            ts2 = ts2 * norm_fstd^2;
        end
        [MSE,SMSE,MSLL] = evaluate2(ori_xvec, ori_yvec, ori_xvec_test, ori_yvec_test, tmu, ts2);
        fprintf('%s (Dc size %d): \r\nMSE %6.8f, SMSE %6.4f, MSLL %6.4f\r\n', 'GRBCM++ (VFE)', n_per, MSE,SMSE,MSLL);
%         grbcm2_gr_smse(ki,kj) = SMSE; grbcm2_gr_msll(ki,kj) = MSLL;
        
        sp_opts.global_index = global_index;
        models = aggregation_train_GRBCM_VS_apx(xvec,yvec,idx,sp_opts); % use hyp of vfe
        [tmu,ts2] =  aggregation_predict_GRBCM_VS_apx(xvec_test,models,sp_opts);
        if ynorm==1
            tmu = tmu * norm_fstd + norm_fmean;
            ts2 = ts2 * norm_fstd^2;
        end
        [MSE,SMSE,MSLL] = evaluate2(ori_xvec, ori_yvec, ori_xvec_test, ori_yvec_test, tmu, ts2);
        fprintf('%s (Dc size %d): \r\nMSE %6.8f, SMSE %6.4f, MSLL %6.4f\r\n', 'GRBCM++ (SPGP)', n_per, MSE,SMSE,MSLL);
%         grbcm2_spgp_gr_smse(ki,kj) = SMSE; grbcm2_spgp_gr_msll(ki,kj) = MSLL;
    end   
end
% Out:
% gr =  1
% GRBCM++ (VFE) (Dc size 223):
% MSE 141.81793784, SMSE 0.1214, MSLL -1.1632
% GRBCM++ (SPGP) (Dc size 223):
% MSE 148.84334677, SMSE 0.1274, MSLL -1.1426
% gr =  1
% GRBCM++ (VFE) (Dc size 223):
% MSE 141.81793784, SMSE 0.1214, MSLL -1.1632
% GRBCM++ (SPGP) (Dc size 223):
% MSE 148.84334677, SMSE 0.1274, MSLL -1.1426
% gr =  1
% GRBCM++ (VFE) (Dc size 223):
% MSE 141.81793784, SMSE 0.1214, MSLL -1.1632
% GRBCM++ (SPGP) (Dc size 223):
% MSE 148.84334677, SMSE 0.1274, MSLL -1.1426

% %%
save(exp_name)
